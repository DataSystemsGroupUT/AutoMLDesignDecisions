# %%
import pandas
import researchpy as rp
import seaborn as sns

import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp

# %% [markdown]
# # Analysis <font color=blue>after </font> combining RF, DT and SVM into 1C

# %%
df = pandas.read_excel(r"C:\Users\HassanEldeeb\Documents\GitHub\AutoMLBenchmarking\logs_search_space/skout.xlsx")
df = df[['dataset', 'time_budget', 'methods', 'f1score']]
df.methods = df.methods.replace("['adaboost', 'bernoulli_nb', 'decision_tree', 'extra_trees', 'gaussian_nb', 'gradient_boosting', 'k_nearest_neighbors', 'lda', 'liblinear_svc', 'libsvm_svc', 'multinomial_nb', 'passive_aggressive', 'qda', 'random_forest', 'sgd']", "fc")
df.methods = df.methods.replace("['decision_tree', 'libsvm_svc', 'random_forest']", "3c")
df.methods = df.methods.replace("['decision_tree', 'random_forest', 'libsvm_svc']", "3c")
df.methods = df.methods.replace("['libsvm_svc']", "1c")
df.methods = df.methods.replace("['decision_tree']", "1c")
df.methods = df.methods.replace("['random_forest']", "1c")
fsIs_b = ['vowel', 'openml_phpJNxH0q', 'dataset_31_credit-g', 'dataset_40_sonar']
fsIs_m = ['solar-flare_1', 'wine-quality-red', 'dataset_39_ecoli', 'synthetic_control']
fsIl_b = ['AirlinesCodrnaAdult', 'MagicTelescope', 'electricity-normalized', 'phpmPOD5A']
fsIl_m = ['pokerhand-normalized', 'eye_movements', 'avila-tr']
flIs_b = ['audiology', 'arrhythmia', 'AP_Breast_Lung', 'AP_Omentum_Ovary']
flIs_m = ['Amazon', 'umistfacescropped', 'phpGUrE90']
flIl_b = ['gina_agnostic', 'hiva_agnostic', 'phpZrCzJR', 'phprAeXmK']
flIl_m = ['KDDCup99', 'connect-4', 'dataset_60_waveform-5000', 'dataset_186_satimage']
df_binary = df[df.dataset.isin(fsIs_b) | df.dataset.isin(fsIl_b) | df.dataset.isin(flIs_b) | df.dataset.isin(flIl_b)]
df_multi = df[df.dataset.isin(fsIs_m) | df.dataset.isin(fsIl_m) | df.dataset.isin(flIs_m) | df.dataset.isin(flIl_m)]
#df.drop(df[(df.methods=='fc') & ((df.time_budget==30) | (df.time_budget==10))].index, inplace=True)
#df.drop(df[(df.methods=='3c') & ((df.time_budget==60) | (df.time_budget==10))].index, inplace=True)
df.shape
# Out:
# (1350, 4)

# %%
rp.summary_cont(df['f1score'])
# Out:
#   Variable       N      Mean       SD        SE  95% Conf.  Interval
# 0  f1score  1350.0  0.808018  0.19422  0.005286   0.797648  0.818387

# %%
rp.summary_cont(df.groupby(['time_budget']))['f1score']
# Out:
#                N      Mean        SD        SE  95% Conf.  Interval
# time_budget
# 10           450  0.795257  0.216084  0.010186   0.775292  0.815222
# 30           450  0.815889  0.182823  0.008618   0.798997  0.832781
# 60           450  0.812907  0.181568  0.008559   0.796131  0.829683

# %%
rp.summary_cont(df.groupby(['methods']))['f1score']
# Out:
#                                                     N      Mean        SD  \
# methods
# 1c                                                810  0.788918  0.213859
# 3c                                                180  0.800090  0.173321
# ['decision_tree', 'random_forest', 'libsvm_svc']   90  0.898257  0.102735
# fc                                                270  0.840522  0.152361
#
#                                                         SE  95% Conf.  \
# methods
# 1c                                                0.007514   0.774190
# 3c                                                0.012919   0.774770
# ['decision_tree', 'random_forest', 'libsvm_svc']  0.010829   0.877032
# fc                                                0.009272   0.822348
#
#                                                   Interval
# methods
# 1c                                                0.803646
# 3c                                                0.825411
# ['decision_tree', 'random_forest', 'libsvm_svc']  0.919482
# fc                                                0.858696

# %%
rp.summary_cont(df.groupby(['time_budget', 'methods']))['f1score']
# Out:
#                                                                 N      Mean  \
# time_budget methods
# 10          1c                                                270  0.770679
#             3c                                                 60  0.803653
#             ['decision_tree', 'random_forest', 'libsvm_svc']   30  0.881400
#             fc                                                 90  0.834680
# 30          1c                                                270  0.799662
#             3c                                                 60  0.808447
#             ['decision_tree', 'random_forest', 'libsvm_svc']   30  0.906675
#             fc                                                 90  0.839267
# 60          1c                                                270  0.796412
#             3c                                                 60  0.788171
#             ['decision_tree', 'random_forest', 'libsvm_svc']   30  0.906697
#             fc                                                 90  0.847619
#
#                                                                     SD  \
# time_budget methods
# 10          1c                                                0.242430
#             3c                                                0.175935
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.132302
#             fc                                                0.160454
# 30          1c                                                0.200472
#             3c                                                0.163428
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.084939
#             fc                                                0.151426
# 60          1c                                                0.195141
#             3c                                                0.182343
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.085040
#             fc                                                0.146290
#
#                                                                     SE  \
# time_budget methods
# 10          1c                                                0.014754
#             3c                                                0.022713
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.024155
#             fc                                                0.016913
# 30          1c                                                0.012200
#             3c                                                0.021098
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.015508
#             fc                                                0.015962
# 60          1c                                                0.011876
#             3c                                                0.023540
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.015526
#             fc                                                0.015420
#
#                                                               95% Conf.  \
# time_budget methods
# 10          1c                                                 0.741762
#             3c                                                 0.759135
#             ['decision_tree', 'random_forest', 'libsvm_svc']   0.834056
#             fc                                                 0.801530
# 30          1c                                                 0.775750
#             3c                                                 0.767094
#             ['decision_tree', 'random_forest', 'libsvm_svc']   0.876280
#             fc                                                 0.807982
# 60          1c                                                 0.773135
#             3c                                                 0.742031
#             ['decision_tree', 'random_forest', 'libsvm_svc']   0.876266
#             fc                                                 0.817395
#
#                                                               Interval
# time_budget methods
# 10          1c                                                0.799597
#             3c                                                0.848171
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.928744
#             fc                                                0.867830
# 30          1c                                                0.823575
#             3c                                                0.849799
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.937070
#             fc                                                0.870552
# 60          1c                                                0.819689
#             3c                                                0.834310
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.937128
#             fc                                                0.877843

# %%
    # Fits the model with the interaction term
    # This will also automatically include the main effects for each factor
    model = ols('f1score ~ C(time_budget)*C(methods)', df).fit()

    # Seeing if the overall model is significant
    print(f"Overall model F({model.df_model: .0f},{model.df_resid: .0f}) = {model.fvalue: .3f}, p = {model.f_pvalue: .4f}")
# Out:
# Overall model F( 11, 1338) =  3.682, p =  0.0000

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                f1score   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     3.682
# Date:                Sun, 03 Nov 2019   Prob (F-statistic):           3.53e-05
# Time:                        16:54:47   Log-Likelihood:                 317.39
# No. Observations:                1350   AIC:                            -610.8
# Df Residuals:                    1338   BIC:                            -548.3
# Df Model:                          11
# Covariance Type:            nonrobust
# =======================================================================================================================================================
#                                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                               0.7707      0.012     65.911      0.000       0.748       0.794
# C(time_budget)[T.30]                                                                    0.0290      0.017      1.753      0.080      -0.003       0.061
# C(time_budget)[T.60]                                                                    0.0257      0.017      1.556      0.120      -0.007       0.058
# C(methods)[T.3c]                                                                        0.0330      0.027      1.202      0.229      -0.021       0.087
# C(methods)[T.['decision_tree', 'random_forest', 'libsvm_svc']]                          0.1107      0.037      2.994      0.003       0.038       0.183
# C(methods)[T.fc]                                                                        0.0640      0.023      2.737      0.006       0.018       0.110
# C(time_budget)[T.30]:C(methods)[T.3c]                                                  -0.0242      0.039     -0.624      0.533      -0.100       0.052
# C(time_budget)[T.60]:C(methods)[T.3c]                                                  -0.0412      0.039     -1.063      0.288      -0.117       0.035
# C(time_budget)[T.30]:C(methods)[T.['decision_tree', 'random_forest', 'libsvm_svc']]    -0.0037      0.052     -0.071      0.943      -0.106       0.099
# C(time_budget)[T.60]:C(methods)[T.['decision_tree', 'random_forest', 'libsvm_svc']]    -0.0004      0.052     -0.008      0.993      -0.103       0.102
# C(time_budget)[T.30]:C(methods)[T.fc]                                                  -0.0244      0.033     -0.738      0.461      -0.089       0.040
# C(time_budget)[T.60]:C(methods)[T.fc]                                                  -0.0128      0.033     -0.387      0.699      -0.078       0.052
# ==============================================================================
# Omnibus:                      443.348   Durbin-Watson:                   0.410
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1300.643
# Skew:                          -1.681   Prob(JB):                    3.71e-283
# Kurtosis:                       6.439   Cond. No.                         16.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Creates the ANOVA table
res = sm.stats.anova_lm(model, typ= 2)
res
# Out:
#                               sum_sq      df          F        PR(>F)
# C(time_budget)              0.111910     2.0   1.515813  2.200066e-01
# C(methods)                  1.324949     3.0  11.964225  9.868779e-08
# C(time_budget):C(methods)   0.058249     6.0   0.262994  9.540476e-01
# Residual                   49.391188  1338.0        NaN           NaN

# %%
# Fits the model
model2 = ols('f1score ~ C(time_budget)+ C(methods)', df).fit()

print(f"Overall model F({model2.df_model: .0f},{model2.df_resid: .0f}) = {model2.fvalue: .3f}, p = {model2.f_pvalue: .4f}")
# Out:
# Overall model F( 5, 1344) =  7.811, p =  0.0000

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                f1score   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     7.811
# Date:                Sun, 03 Nov 2019   Prob (F-statistic):           2.94e-07
# Time:                        16:54:47   Log-Likelihood:                 316.60
# No. Observations:                1350   AIC:                            -621.2
# Df Residuals:                    1344   BIC:                            -589.9
# Df Model:                           5
# Covariance Type:            nonrobust
# ==================================================================================================================================
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                          0.7762      0.010     77.643      0.000       0.757       0.796
# C(time_budget)[T.30]                                               0.0206      0.013      1.613      0.107      -0.004       0.046
# C(time_budget)[T.60]                                               0.0176      0.013      1.380      0.168      -0.007       0.043
# C(methods)[T.3c]                                                   0.0112      0.016      0.707      0.480      -0.020       0.042
# C(methods)[T.['decision_tree', 'random_forest', 'libsvm_svc']]     0.1093      0.021      5.130      0.000       0.068       0.151
# C(methods)[T.fc]                                                   0.0516      0.013      3.828      0.000       0.025       0.078
# ==============================================================================
# Omnibus:                      446.050   Durbin-Watson:                   0.410
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1319.447
# Skew:                          -1.687   Prob(JB):                    3.06e-287
# Kurtosis:                       6.474   Cond. No.                         4.83
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Creates the ANOVA table
res2 = sm.stats.anova_lm(model2, typ= 2)
res2
# Out:
#                    sum_sq      df          F        PR(>F)
# C(time_budget)   0.111910     2.0   1.520816  2.189092e-01
# C(methods)       1.324949     3.0  12.003720  9.320500e-08
# Residual        49.449437  1344.0        NaN           NaN

# %%
# Calculating effect size
def anova_table(aov):
    aov['mean_sq'] = aov[:]['sum_sq']/aov[:]['df']
    
    aov['eta_sq'] = aov[:-1]['sum_sq']/sum(aov['sum_sq'])
    
    aov['omega_sq'] = (aov[:-1]['sum_sq']-(aov[:-1]['df']*aov['mean_sq'][-1]))/(sum(aov['sum_sq'])+aov['mean_sq'][-1])
    
    cols = ['sum_sq', 'mean_sq', 'df', 'F', 'PR(>F)', 'eta_sq', 'omega_sq']
    aov = aov[cols]
    return aov

anova_table(res2)
# Out:
#                    sum_sq   mean_sq      df          F        PR(>F)  \
# C(time_budget)   0.111910  0.055955     2.0   1.520816  2.189092e-01
# C(methods)       1.324949  0.441650     3.0  12.003720  9.320500e-08
# Residual        49.449437  0.036793  1344.0        NaN           NaN
#
#                   eta_sq  omega_sq
# C(time_budget)  0.002199  0.000753
# C(methods)      0.026037  0.023851
# Residual             NaN       NaN

# %%
mc = statsmodels.stats.multicomp.MultiComparison(df['f1score'], df['methods'])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
#                                           Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================================================================================================
#                      group1                                           group2                      meandiff p-adj   lower  upper  reject
# ---------------------------------------------------------------------------------------------------------------------------------------
#                                               1c                                               3c   0.0112 0.8886 -0.0295 0.0518  False
#                                               1c ['decision_tree', 'random_forest', 'libsvm_svc']   0.1093  0.001  0.0545 0.1642   True
#                                               1c                                               fc   0.0516  0.001  0.0169 0.0863   True
#                                               3c ['decision_tree', 'random_forest', 'libsvm_svc']   0.0982  0.001  0.0344 0.1619   True
#                                               3c                                               fc   0.0404 0.1264 -0.0071 0.0879  False
# ['decision_tree', 'random_forest', 'libsvm_svc']                                               fc  -0.0577 0.0649 -0.1178 0.0023  False
# ---------------------------------------------------------------------------------------------------------------------------------------

# %%
mc = statsmodels.stats.multicomp.MultiComparison(df['f1score'], df['time_budget'])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     10     30   0.0206 0.2489 -0.0097  0.051  False
#     10     60   0.0176 0.3615 -0.0127  0.048  False
#     30     60   -0.003    0.9 -0.0334 0.0274  False
# ---------------------------------------------------

# %% [markdown]
# # Analysis <font color=blue>without </font> combining RF, DT and SVM into 1C

# %%
df = pandas.read_excel(r"C:\Users\HassanEldeeb\Documents\GitHub\AutoMLBenchmarking\logs_search_space/skout.xlsx")
df = df[['time_budget', 'methods', 'f1score']]
df.methods = df.methods.replace("['adaboost', 'bernoulli_nb', 'decision_tree', 'extra_trees', 'gaussian_nb', 'gradient_boosting', 'k_nearest_neighbors', 'lda', 'liblinear_svc', 'libsvm_svc', 'multinomial_nb', 'passive_aggressive', 'qda', 'random_forest', 'sgd']", "fc")
df.methods = df.methods.replace("['decision_tree', 'libsvm_svc', 'random_forest']", "3c")
df.methods = df.methods.replace("['libsvm_svc']", "svm")
df.methods = df.methods.replace("['decision_tree']", "DT")
df.methods = df.methods.replace("['random_forest']", "RF")
#df.drop(df[(df.methods=='fc') & ((df.time_budget==30) | (df.time_budget==10))].index, inplace=True)
#df.drop(df[(df.methods=='3c') & ((df.time_budget==60) | (df.time_budget==10))].index, inplace=True)
df.shape
# Out:
# (1350, 3)

# %%
rp.summary_cont(df['f1score'])
# Out:
#   Variable       N      Mean       SD        SE  95% Conf.  Interval
# 0  f1score  1350.0  0.808018  0.19422  0.005286   0.797648  0.818387

# %%
rp.summary_cont(df.groupby(['time_budget']))['f1score']
# Out:
#                N      Mean        SD        SE  95% Conf.  Interval
# time_budget
# 10           450  0.795257  0.216084  0.010186   0.775292  0.815222
# 30           450  0.815889  0.182823  0.008618   0.798997  0.832781
# 60           450  0.812907  0.181568  0.008559   0.796131  0.829683

# %%
rp.summary_cont(df.groupby(['methods']))['f1score']
# Out:
#                                                     N      Mean        SD  \
# methods
# 3c                                                180  0.800090  0.173321
# DT                                                270  0.793107  0.188630
# RF                                                270  0.824734  0.172256
# ['decision_tree', 'random_forest', 'libsvm_svc']   90  0.898257  0.102735
# fc                                                270  0.840522  0.152361
# svm                                               270  0.748912  0.263406
#
#                                                         SE  95% Conf.  \
# methods
# 3c                                                0.012919   0.774770
# DT                                                0.011480   0.770607
# RF                                                0.010483   0.804187
# ['decision_tree', 'random_forest', 'libsvm_svc']  0.010829   0.877032
# fc                                                0.009272   0.822348
# svm                                               0.016030   0.717493
#
#                                                   Interval
# methods
# 3c                                                0.825411
# DT                                                0.815607
# RF                                                0.845282
# ['decision_tree', 'random_forest', 'libsvm_svc']  0.919482
# fc                                                0.858696
# svm                                               0.780332

# %%
rp.summary_cont(df.groupby(['time_budget', 'methods']))['f1score']
# Out:
#                                                                N      Mean  \
# time_budget methods
# 10          3c                                                60  0.803653
#             DT                                                90  0.778558
#             RF                                                90  0.818641
#             ['decision_tree', 'random_forest', 'libsvm_svc']  30  0.881400
#             fc                                                90  0.834680
#             svm                                               90  0.714839
# 30          3c                                                60  0.808447
#             DT                                                90  0.802777
#             RF                                                90  0.838081
#             ['decision_tree', 'random_forest', 'libsvm_svc']  30  0.906675
#             fc                                                90  0.839267
#             svm                                               90  0.758129
# 60          3c                                                60  0.788171
#             DT                                                90  0.797986
#             RF                                                90  0.817481
#             ['decision_tree', 'random_forest', 'libsvm_svc']  30  0.906697
#             fc                                                90  0.847619
#             svm                                               90  0.773769
#
#                                                                     SD  \
# time_budget methods
# 10          3c                                                0.175935
#             DT                                                0.208695
#             RF                                                0.199986
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.132302
#             fc                                                0.160454
#             svm                                               0.297571
# 30          3c                                                0.163428
#             DT                                                0.180722
#             RF                                                0.155413
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.084939
#             fc                                                0.151426
#             svm                                               0.247810
# 60          3c                                                0.182343
#             DT                                                0.176059
#             RF                                                0.158949
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.085040
#             fc                                                0.146290
#             svm                                               0.240550
#
#                                                                     SE  \
# time_budget methods
# 10          3c                                                0.022713
#             DT                                                0.021998
#             RF                                                0.021080
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.024155
#             fc                                                0.016913
#             svm                                               0.031367
# 30          3c                                                0.021098
#             DT                                                0.019050
#             RF                                                0.016382
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.015508
#             fc                                                0.015962
#             svm                                               0.026121
# 60          3c                                                0.023540
#             DT                                                0.018558
#             RF                                                0.016755
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.015526
#             fc                                                0.015420
#             svm                                               0.025356
#
#                                                               95% Conf.  \
# time_budget methods
# 10          3c                                                 0.759135
#             DT                                                 0.735441
#             RF                                                 0.777323
#             ['decision_tree', 'random_forest', 'libsvm_svc']   0.834056
#             fc                                                 0.801530
#             svm                                                0.653360
# 30          3c                                                 0.767094
#             DT                                                 0.765440
#             RF                                                 0.805972
#             ['decision_tree', 'random_forest', 'libsvm_svc']   0.876280
#             fc                                                 0.807982
#             svm                                                0.706931
# 60          3c                                                 0.742031
#             DT                                                 0.761612
#             RF                                                 0.784642
#             ['decision_tree', 'random_forest', 'libsvm_svc']   0.876266
#             fc                                                 0.817395
#             svm                                                0.724071
#
#                                                               Interval
# time_budget methods
# 10          3c                                                0.848171
#             DT                                                0.821674
#             RF                                                0.859959
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.928744
#             fc                                                0.867830
#             svm                                               0.776318
# 30          3c                                                0.849799
#             DT                                                0.840115
#             RF                                                0.870190
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.937070
#             fc                                                0.870552
#             svm                                               0.809327
# 60          3c                                                0.834310
#             DT                                                0.834360
#             RF                                                0.850320
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.937128
#             fc                                                0.877843
#             svm                                               0.823467

# %%
    # Fits the model with the interaction term
    # This will also automatically include the main effects for each factor
    model = ols('f1score ~ C(time_budget)*C(methods)', df).fit()

    # Seeing if the overall model is significant
    print(f"Overall model F({model.df_model: .0f},{model.df_resid: .0f}) = {model.fvalue: .3f}, p = {model.f_pvalue: .4f}")
# Out:
# Overall model F( 17, 1332) =  3.817, p =  0.0000

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                f1score   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     3.817
# Date:                Sun, 03 Nov 2019   Prob (F-statistic):           2.54e-07
# Time:                        16:54:48   Log-Likelihood:                 329.37
# No. Observations:                1350   AIC:                            -622.7
# Df Residuals:                    1332   BIC:                            -529.0
# Df Model:                          17
# Covariance Type:            nonrobust
# =======================================================================================================================================================
#                                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                               0.8037      0.025     32.615      0.000       0.755       0.852
# C(time_budget)[T.30]                                                                    0.0048      0.035      0.138      0.891      -0.064       0.073
# C(time_budget)[T.60]                                                                   -0.0155      0.035     -0.444      0.657      -0.084       0.053
# C(methods)[T.DT]                                                                       -0.0251      0.032     -0.789      0.430      -0.087       0.037
# C(methods)[T.RF]                                                                        0.0150      0.032      0.471      0.638      -0.047       0.077
# C(methods)[T.['decision_tree', 'random_forest', 'libsvm_svc']]                          0.0777      0.043      1.822      0.069      -0.006       0.161
# C(methods)[T.fc]                                                                        0.0310      0.032      0.975      0.330      -0.031       0.093
# C(methods)[T.svm]                                                                      -0.0888      0.032     -2.792      0.005      -0.151      -0.026
# C(time_budget)[T.30]:C(methods)[T.DT]                                                   0.0194      0.045      0.432      0.666      -0.069       0.108
# C(time_budget)[T.60]:C(methods)[T.DT]                                                   0.0349      0.045      0.776      0.438      -0.053       0.123
# C(time_budget)[T.30]:C(methods)[T.RF]                                                   0.0146      0.045      0.326      0.745      -0.074       0.103
# C(time_budget)[T.60]:C(methods)[T.RF]                                                   0.0143      0.045      0.318      0.750      -0.074       0.103
# C(time_budget)[T.30]:C(methods)[T.['decision_tree', 'random_forest', 'libsvm_svc']]     0.0205      0.060      0.339      0.734      -0.098       0.139
# C(time_budget)[T.60]:C(methods)[T.['decision_tree', 'random_forest', 'libsvm_svc']]     0.0408      0.060      0.676      0.499      -0.078       0.159
# C(time_budget)[T.30]:C(methods)[T.fc]                                                  -0.0002      0.045     -0.005      0.996      -0.088       0.088
# C(time_budget)[T.60]:C(methods)[T.fc]                                                   0.0284      0.045      0.632      0.528      -0.060       0.117
# C(time_budget)[T.30]:C(methods)[T.svm]                                                  0.0385      0.045      0.856      0.392      -0.050       0.127
# C(time_budget)[T.60]:C(methods)[T.svm]                                                  0.0744      0.045      1.654      0.098      -0.014       0.163
# ==============================================================================
# Omnibus:                      406.728   Durbin-Watson:                   0.409
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1078.388
# Skew:                          -1.582   Prob(JB):                    6.78e-235
# Kurtosis:                       6.027   Cond. No.                         28.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Creates the ANOVA table
res = sm.stats.anova_lm(model, typ= 2)
res
# Out:
#                               sum_sq      df          F        PR(>F)
# C(time_budget)              0.111910     2.0   1.536026  2.156158e-01
# C(methods)                  2.108171     5.0  11.574320  5.794125e-11
# C(time_budget):C(methods)   0.143559    10.0   0.394085  9.497136e-01
# Residual                   48.522656  1332.0        NaN           NaN

# %%
# Fits the model
model2 = ols('f1score ~ C(time_budget)+ C(methods)', df).fit()

print(f"Overall model F({model2.df_model: .0f},{model2.df_resid: .0f}) = {model2.fvalue: .3f}, p = {model2.f_pvalue: .4f}")
# Out:
# Overall model F( 7, 1342) =  8.746, p =  0.0000

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                f1score   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     8.746
# Date:                Sun, 03 Nov 2019   Prob (F-statistic):           1.53e-10
# Time:                        16:54:48   Log-Likelihood:                 327.37
# No. Observations:                1350   AIC:                            -638.7
# Df Residuals:                    1342   BIC:                            -597.1
# Df Model:                           7
# Covariance Type:            nonrobust
# ==================================================================================================================================
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                          0.7873      0.016     49.286      0.000       0.756       0.819
# C(time_budget)[T.30]                                               0.0206      0.013      1.625      0.104      -0.004       0.046
# C(time_budget)[T.60]                                               0.0176      0.013      1.390      0.165      -0.007       0.043
# C(methods)[T.DT]                                                  -0.0070      0.018     -0.381      0.703      -0.043       0.029
# C(methods)[T.RF]                                                   0.0246      0.018      1.345      0.179      -0.011       0.061
# C(methods)[T.['decision_tree', 'random_forest', 'libsvm_svc']]     0.0982      0.025      3.993      0.000       0.050       0.146
# C(methods)[T.fc]                                                   0.0404      0.018      2.206      0.028       0.004       0.076
# C(methods)[T.svm]                                                 -0.0512      0.018     -2.793      0.005      -0.087      -0.015
# ==============================================================================
# Omnibus:                      410.560   Durbin-Watson:                   0.410
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1099.848
# Skew:                          -1.592   Prob(JB):                    1.48e-239
# Kurtosis:                       6.068   Cond. No.                         8.53
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Creates the ANOVA table
res2 = sm.stats.anova_lm(model2, typ= 2)
res2
# Out:
#                    sum_sq      df          F        PR(>F)
# C(time_budget)   0.111910     2.0   1.542993  2.141195e-01
# C(methods)       2.108171     5.0  11.626816  5.120948e-11
# Residual        48.666215  1342.0        NaN           NaN

# %%
# Calculating effect size
def anova_table(aov):
    aov['mean_sq'] = aov[:]['sum_sq']/aov[:]['df']
    
    aov['eta_sq'] = aov[:-1]['sum_sq']/sum(aov['sum_sq'])
    
    aov['omega_sq'] = (aov[:-1]['sum_sq']-(aov[:-1]['df']*aov['mean_sq'][-1]))/(sum(aov['sum_sq'])+aov['mean_sq'][-1])
    
    cols = ['sum_sq', 'mean_sq', 'df', 'F', 'PR(>F)', 'eta_sq', 'omega_sq']
    aov = aov[cols]
    return aov

anova_table(res2)
# Out:
#                    sum_sq   mean_sq      df          F        PR(>F)  \
# C(time_budget)   0.111910  0.055955     2.0   1.542993  2.141195e-01
# C(methods)       2.108171  0.421634     5.0  11.626816  5.120948e-11
# Residual        48.666215  0.036264  1342.0        NaN           NaN
#
#                   eta_sq  omega_sq
# C(time_budget)  0.002199  0.000773
# C(methods)      0.041429  0.037839
# Residual             NaN       NaN

# %%
mc = statsmodels.stats.multicomp.MultiComparison(df['f1score'], df['methods'])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
#                                           Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================================================================================================
#                      group1                                           group2                      meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------------------------------------------------------------------------------
#                                               3c                                               DT   -0.007    0.9 -0.0593  0.0453  False
#                                               3c                                               RF   0.0246 0.7325 -0.0277   0.077  False
#                                               3c ['decision_tree', 'random_forest', 'libsvm_svc']   0.0982  0.001   0.028  0.1684   True
#                                               3c                                               fc   0.0404 0.2357 -0.0119  0.0927  False
#                                               3c                                              svm  -0.0512 0.0595 -0.1035  0.0011  False
#                                               DT                                               RF   0.0316 0.3862 -0.0152  0.0784  False
#                                               DT ['decision_tree', 'random_forest', 'libsvm_svc']   0.1052  0.001   0.039  0.1713   True
#                                               DT                                               fc   0.0474 0.0449  0.0006  0.0942   True
#                                               DT                                              svm  -0.0442  0.077  -0.091  0.0026  False
#                                               RF ['decision_tree', 'random_forest', 'libsvm_svc']   0.0735 0.0194  0.0073  0.1397   True
#                                               RF                                               fc   0.0158    0.9  -0.031  0.0626  False
#                                               RF                                              svm  -0.0758  0.001 -0.1226  -0.029   True
# ['decision_tree', 'random_forest', 'libsvm_svc']                                               fc  -0.0577 0.1274 -0.1239  0.0084  False
# ['decision_tree', 'random_forest', 'libsvm_svc']                                              svm  -0.1493  0.001 -0.2155 -0.0832   True
#                                               fc                                              svm  -0.0916  0.001 -0.1384 -0.0448   True
# ----------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Analysis <font color=blue>after </font> combining RF, DT and SVM into 1C
# # Comparing FC (60 min) with 3C(30)

# %%
df = pandas.read_excel(r"C:\Users\HassanEldeeb\Documents\GitHub\AutoMLBenchmarking\logs_search_space/skout.xlsx")
df = df[['time_budget', 'methods', 'f1score']]
df.methods = df.methods.replace("['adaboost', 'bernoulli_nb', 'decision_tree', 'extra_trees', 'gaussian_nb', 'gradient_boosting', 'k_nearest_neighbors', 'lda', 'liblinear_svc', 'libsvm_svc', 'multinomial_nb', 'passive_aggressive', 'qda', 'random_forest', 'sgd']", "fc")
df.methods = df.methods.replace("['decision_tree', 'libsvm_svc', 'random_forest']", "3c")
df.methods = df.methods.replace("['libsvm_svc']", "1c")
df.methods = df.methods.replace("['decision_tree']", "1c")
df.methods = df.methods.replace("['random_forest']", "1c")
df.drop(df[(df.methods=='fc') & ((df.time_budget==30) | (df.time_budget==10))].index, inplace=True)
df.drop(df[(df.methods=='3c') & ((df.time_budget==60) | (df.time_budget==10))].index, inplace=True)
df.drop(df[(df.methods=='1c') & ((df.time_budget==60) | (df.time_budget==10))].index, inplace=True)
df.shape
# Out:
# (510, 3)

# %%
rp.summary_cont(df['f1score'])
# Out:
#   Variable      N      Mean       SD        SE  95% Conf.  Interval
# 0  f1score  510.0  0.826558  0.17701  0.007838   0.811159  0.841957

# %%
rp.summary_cont(df.groupby(['time_budget']))['f1score']
# Out:
#                N      Mean        SD        SE  95% Conf.  Interval
# time_budget
# 10            30  0.881400  0.132302  0.024155   0.834056  0.928744
# 30           360  0.810044  0.189599  0.009993   0.790458  0.829630
# 60           120  0.862389  0.135749  0.012392   0.838100  0.886677

# %%
rp.summary_cont(df.groupby(['methods']))['f1score']
# Out:
#                                                     N      Mean        SD  \
# methods
# 1c                                                270  0.799662  0.200472
# 3c                                                 60  0.808447  0.163428
# ['decision_tree', 'random_forest', 'libsvm_svc']   90  0.898257  0.102735
# fc                                                 90  0.847619  0.146290
#
#                                                         SE  95% Conf.  \
# methods
# 1c                                                0.012200   0.775750
# 3c                                                0.021098   0.767094
# ['decision_tree', 'random_forest', 'libsvm_svc']  0.010829   0.877032
# fc                                                0.015420   0.817395
#
#                                                   Interval
# methods
# 1c                                                0.823575
# 3c                                                0.849799
# ['decision_tree', 'random_forest', 'libsvm_svc']  0.919482
# fc                                                0.877843

# %%
rp.summary_cont(df.groupby(['time_budget', 'methods']))['f1score']
# Out:
#                                                                 N      Mean  \
# time_budget methods
# 10          ['decision_tree', 'random_forest', 'libsvm_svc']   30  0.881400
# 30          1c                                                270  0.799662
#             3c                                                 60  0.808447
#             ['decision_tree', 'random_forest', 'libsvm_svc']   30  0.906675
# 60          ['decision_tree', 'random_forest', 'libsvm_svc']   30  0.906697
#             fc                                                 90  0.847619
#
#                                                                     SD  \
# time_budget methods
# 10          ['decision_tree', 'random_forest', 'libsvm_svc']  0.132302
# 30          1c                                                0.200472
#             3c                                                0.163428
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.084939
# 60          ['decision_tree', 'random_forest', 'libsvm_svc']  0.085040
#             fc                                                0.146290
#
#                                                                     SE  \
# time_budget methods
# 10          ['decision_tree', 'random_forest', 'libsvm_svc']  0.024155
# 30          1c                                                0.012200
#             3c                                                0.021098
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.015508
# 60          ['decision_tree', 'random_forest', 'libsvm_svc']  0.015526
#             fc                                                0.015420
#
#                                                               95% Conf.  \
# time_budget methods
# 10          ['decision_tree', 'random_forest', 'libsvm_svc']   0.834056
# 30          1c                                                 0.775750
#             3c                                                 0.767094
#             ['decision_tree', 'random_forest', 'libsvm_svc']   0.876280
# 60          ['decision_tree', 'random_forest', 'libsvm_svc']   0.876266
#             fc                                                 0.817395
#
#                                                               Interval
# time_budget methods
# 10          ['decision_tree', 'random_forest', 'libsvm_svc']  0.928744
# 30          1c                                                0.823575
#             3c                                                0.849799
#             ['decision_tree', 'random_forest', 'libsvm_svc']  0.937070
# 60          ['decision_tree', 'random_forest', 'libsvm_svc']  0.937128
#             fc                                                0.877843

# %%
    # Fits the model with the interaction term
    # This will also automatically include the main effects for each factor
    model = ols('f1score ~ C(time_budget)*C(methods)', df).fit()

    # Seeing if the overall model is significant
    print(f"Overall model F({model.df_model: .0f},{model.df_resid: .0f}) = {model.fvalue: .3f}, p = {model.f_pvalue: .4f}")
# Out:
# Overall model F( 5, 504) =  4.838, p =  0.0002

# %%
model.summary()
# Out:
# C:\Users\HassanEldeeb\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1755: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# C:\Users\HassanEldeeb\Anaconda3\lib\site-packages\statsmodels\base\model.py:1294: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# C:\Users\HassanEldeeb\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\HassanEldeeb\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Users\HassanEldeeb\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1892: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                f1score   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     4.838
# Date:                Sun, 03 Nov 2019   Prob (F-statistic):           0.000248
# Time:                        16:54:49   Log-Likelihood:                 171.89
# No. Observations:                 510   AIC:                            -331.8
# Df Residuals:                     504   BIC:                            -306.4
# Df Model:                           5
# Covariance Type:            nonrobust
# =======================================================================================================================================================
#                                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                               0.6340      0.018     34.816      0.000       0.598       0.670
# C(time_budget)[T.30]                                                                    0.1657      0.018      8.964      0.000       0.129       0.202
# C(time_budget)[T.60]                                                                    0.0529      0.021      2.536      0.011       0.012       0.094
# C(methods)[T.3c]                                                                        0.0044      0.012      0.354      0.723      -0.020       0.029
# C(methods)[T.['decision_tree', 'random_forest', 'libsvm_svc']]                          0.2474      0.018     13.589      0.000       0.212       0.283
# C(methods)[T.fc]                                                                        0.0804      0.009      8.492      0.000       0.062       0.099
# C(time_budget)[T.30]:C(methods)[T.3c]                                                   0.0044      0.012      0.354      0.723      -0.020       0.029
# C(time_budget)[T.60]:C(methods)[T.3c]                                                        0          0        nan        nan           0           0
# C(time_budget)[T.30]:C(methods)[T.['decision_tree', 'random_forest', 'libsvm_svc']]    -0.1404      0.030     -4.705      0.000      -0.199      -0.082
# C(time_budget)[T.60]:C(methods)[T.['decision_tree', 'random_forest', 'libsvm_svc']]    -0.0276      0.025     -1.109      0.268      -0.076       0.021
# C(time_budget)[T.30]:C(methods)[T.fc]                                                        0          0        nan        nan           0           0
# C(time_budget)[T.60]:C(methods)[T.fc]                                                   0.0804      0.009      8.492      0.000       0.062       0.099
# ==============================================================================
# Omnibus:                      174.588   Durbin-Watson:                   0.477
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              520.841
# Skew:                          -1.648   Prob(JB):                    7.96e-114
# Kurtosis:                       6.695   Cond. No.                          inf
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# Creates the ANOVA table
res = sm.stats.anova_lm(model, typ= 2)
res
# Out:
# C:\Users\HassanEldeeb\Anaconda3\lib\site-packages\statsmodels\base\model.py:1752: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 2, but rank is 1
#   'rank is %d' % (J, J_), ValueWarning)
# C:\Users\HassanEldeeb\Anaconda3\lib\site-packages\statsmodels\base\model.py:1752: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   'rank is %d' % (J, J_), ValueWarning)
# C:\Users\HassanEldeeb\Anaconda3\lib\site-packages\statsmodels\base\model.py:1752: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 6, but rank is 4
#   'rank is %d' % (J, J_), ValueWarning)
#                               sum_sq     df           F        PR(>F)
# C(time_budget)             34.201504    2.0  566.359537  1.815443e-84
# C(methods)                 31.211502    3.0  344.564421  4.867259e-95
# C(time_budget):C(methods)  12.718990    6.0   70.206672  3.085757e-47
# Residual                   15.217858  504.0         NaN           NaN

# %%
# Fits the model
model2 = ols('f1score ~ C(time_budget)+ C(methods)', df).fit()

print(f"Overall model F({model2.df_model: .0f},{model2.df_resid: .0f}) = {model2.fvalue: .3f}, p = {model2.f_pvalue: .4f}")
# Out:
# Overall model F( 5, 504) =  4.838, p =  0.0002

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                f1score   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     4.838
# Date:                Sun, 03 Nov 2019   Prob (F-statistic):           0.000248
# Time:                        16:54:49   Log-Likelihood:                 171.89
# No. Observations:                 510   AIC:                            -331.8
# Df Residuals:                     504   BIC:                            -306.4
# Df Model:                           5
# Covariance Type:            nonrobust
# ==================================================================================================================================
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                          0.7744      0.046     16.800      0.000       0.684       0.865
# C(time_budget)[T.30]                                               0.0253      0.045      0.563      0.573      -0.063       0.113
# C(time_budget)[T.60]                                               0.0253      0.045      0.564      0.573      -0.063       0.113
# C(methods)[T.3c]                                                   0.0088      0.025      0.354      0.723      -0.040       0.058
# C(methods)[T.['decision_tree', 'random_forest', 'libsvm_svc']]     0.1070      0.033      3.200      0.001       0.041       0.173
# C(methods)[T.fc]                                                   0.0479      0.050      0.966      0.334      -0.050       0.145
# ==============================================================================
# Omnibus:                      174.588   Durbin-Watson:                   0.477
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              520.841
# Skew:                          -1.648   Prob(JB):                    7.96e-114
# Kurtosis:                       6.695   Cond. No.                         12.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Creates the ANOVA table
res2 = sm.stats.anova_lm(model2, typ= 2)
res2
# Out:
#                    sum_sq     df         F    PR(>F)
# C(time_budget)   0.012788    2.0  0.211757  0.809233
# C(methods)       0.387906    3.0  4.282355  0.005336
# Residual        15.217858  504.0       NaN       NaN

# %%
# Calculating effect size
def anova_table(aov):
    aov['mean_sq'] = aov[:]['sum_sq']/aov[:]['df']
    
    aov['eta_sq'] = aov[:-1]['sum_sq']/sum(aov['sum_sq'])
    
    aov['omega_sq'] = (aov[:-1]['sum_sq']-(aov[:-1]['df']*aov['mean_sq'][-1]))/(sum(aov['sum_sq'])+aov['mean_sq'][-1])
    
    cols = ['sum_sq', 'mean_sq', 'df', 'F', 'PR(>F)', 'eta_sq', 'omega_sq']
    aov = aov[cols]
    return aov

anova_table(res2)
# Out:
#                    sum_sq   mean_sq     df         F    PR(>F)    eta_sq  \
# C(time_budget)   0.012788  0.006394    2.0  0.211757  0.809233  0.000819
# C(methods)       0.387906  0.129302    3.0  4.282355  0.005336  0.024836
# Residual        15.217858  0.030194  504.0       NaN       NaN       NaN
#
#                 omega_sq
# C(time_budget) -0.003042
# C(methods)      0.019000
# Residual             NaN

# %%
mc = statsmodels.stats.multicomp.MultiComparison(df['f1score'], df['methods'])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
#                                           Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================================================================================================
#                      group1                                           group2                      meandiff p-adj   lower  upper  reject
# ---------------------------------------------------------------------------------------------------------------------------------------
#                                               1c                                               3c   0.0088    0.9  -0.055 0.0726  False
#                                               1c ['decision_tree', 'random_forest', 'libsvm_svc']   0.0986  0.001  0.0442  0.153   True
#                                               1c                                               fc    0.048 0.1063 -0.0065 0.1024  False
#                                               3c ['decision_tree', 'random_forest', 'libsvm_svc']   0.0898 0.0108  0.0153 0.1643   True
#                                               3c                                               fc   0.0392 0.5252 -0.0354 0.1137  False
# ['decision_tree', 'random_forest', 'libsvm_svc']                                               fc  -0.0506 0.2056 -0.1173  0.016  False
# ---------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Wilcoxon signed-rank test

# %%
df = pandas.read_excel(r"C:\Users\HassanEldeeb\Documents\GitHub\AutoMLBenchmarking\logs_search_space/skout.xlsx")
df = df[['time_budget', 'methods', 'f1score']]
df.methods = df.methods.replace("['adaboost', 'bernoulli_nb', 'decision_tree', 'extra_trees', 'gaussian_nb', 'gradient_boosting', 'k_nearest_neighbors', 'lda', 'liblinear_svc', 'libsvm_svc', 'multinomial_nb', 'passive_aggressive', 'qda', 'random_forest', 'sgd']", "fc")
df.methods = df.methods.replace("['decision_tree', 'libsvm_svc', 'random_forest']", "3c")
df.methods = df.methods.replace("['libsvm_svc']", "svm")
df.methods = df.methods.replace("['decision_tree']", "DT")
df.methods = df.methods.replace("['random_forest']", "RF")
df.shape
# Out:
# (1350, 3)

# %%
# Wilcoxon signed-rank test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import wilcoxon
# seed the random number generator
seed(1)
# generate two independent samples
data1 = df.f1score[df.methods=='3c']
data2 = df.f1score[df.methods=='fc']
# compare samples
stat, p = wilcoxon(data1, data2)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Same distribution (fail to reject H0)')
else:
    print('Different distribution (reject H0)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-5d0642e0b5d4> in <module>
#       9 data2 = df.f1score[df.methods=='fc']
#      10 # compare samples
# ---> 11 stat, p = wilcoxon(data1, data2)
#      12 print('Statistics=%.3f, p=%.3f' % (stat, p))
#      13 # interpret
#
# ~\Anaconda3\lib\site-packages\scipy\stats\morestats.py in wilcoxon(x, y, zero_method, correction, alternative)
#    2846             raise ValueError('Samples x and y must be one-dimensional.')
#    2847         if len(x) != len(y):
# -> 2848             raise ValueError('The samples x and y must have the same length.')
#    2849         d = x - y
#    2850
#
# ValueError: The samples x and y must have the same length.

# %%
df = pandas.read_excel(r"C:\Users\HassanEldeeb\Documents\GitHub\AutoMLBenchmarking\logs_search_space/skout.xlsx")
df = df[['time_budget', 'methods', 'f1score']]
df.methods = df.methods.replace("['adaboost', 'bernoulli_nb', 'decision_tree', 'extra_trees', 'gaussian_nb', 'gradient_boosting', 'k_nearest_neighbors', 'lda', 'liblinear_svc', 'libsvm_svc', 'multinomial_nb', 'passive_aggressive', 'qda', 'random_forest', 'sgd']", "fc")
df.methods = df.methods.replace("['decision_tree', 'libsvm_svc', 'random_forest']", "3c")
df.methods = df.methods.replace("['libsvm_svc']", "svm")
df.methods = df.methods.replace("['decision_tree']", "DT")
df.methods = df.methods.replace("['random_forest']", "RF")
df.shape

# %%
# Wilcoxon signed-rank test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import wilcoxon
# seed the random number generator
seed(1)
# generate two independent samples
data1 = df.f1score[df.methods=='3c']
data2 = df.f1score[df.methods=='fc']
# compare samples
stat, p = wilcoxon(data1, data2)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Same distribution (fail to reject H0)')
else:
    print('Different distribution (reject H0)')
