# %%
import pandas as pd
import subprocess
import argparse
import os
import glob
import signal
import datetime
import time

    
def read_dataset(path):
    # All datasets available
    files_dirs = glob.glob(path + "/*.csv")
    files_dirs.sort()
    return (files_dirs)

# %%
files = read_dataset("C:/Users/s-moh/0-Labwork/Benchmark Experiments/Results/Recipe/recipe60min2")
print(files)
# Out:
# ['C:/Users/s-moh/0-Labwork/Benchmark Experiments/Results/Recipe/recipe60min2\\Result_AP_Breast_Lung_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/Results/Recipe/recipe60min2\\Result_AP_Omentum_Ovary_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/Results/Recipe/recipe60min2\\Result_AirlinesCodrnaAdult_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/Results/Recipe/recipe60min2\\Result_CovPokElec_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/Results/Recipe/recipe60min2\\Result_KDDCup99_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/Results/Recipe/recipe60min2\\Result_dataset_185_yeast_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/Results/Recipe/recipe60min2\\Result_dataset_186_satimage_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/Results/Recipe/recipe60min2\\Result_dataset_187_abalone_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/Results/Recipe/recipe60min2\\Result_dataset_24_mushroom_te
# ...

# %%
for f in files:
    print(f)
    data = pd.read_csv(f, header = None)
    try:
        print(data[15], '\n\n\n')
    except:
        pass
# Out:
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/Results/Recipe/recipe60min2\Result_AP_Breast_Lung_test.csv
# 0    0.965787
# Name: 15, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/Results/Recipe/recipe60min2\Result_AP_Omentum_Ovary_test.csv
# 0    0.729753
# Name: 15, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/Results/Recipe/recipe60min2\Result_AirlinesCodrnaAdult_test.csv
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/Results/Recipe/recipe60min2\Result_CovPokElec_test.csv
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/Results/Recipe/recipe60min2\Result_KDDCup99_test.csv
# 0    0.420478
# Name: 15, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/Results/Recipe/recipe60min2\Result_dataset_185_yeast_test.csv
# 0    0.458501
# Name: 15, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/Results/Recipe/recipe60min2\Result_dataset_186_satimage_test.csv
# 0    0.916861
# ...
