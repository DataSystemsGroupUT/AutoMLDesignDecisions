# %%
import pandas as pd
import subprocess
import argparse
import os
import glob
import signal
import datetime
import time

    
def read_dataset(path):
    # All datasets available
    files_dirs = glob.glob(path + "/*.csv")
    files_dirs.sort()
    return (files_dirs)

# %%
files = read_dataset("C:/Users/s-moh/0-Labwork/Benchmark Experiments/results/Recipe/recipe4hrs/part3")
print(files)
# Out:
# ['C:/Users/s-moh/0-Labwork/Benchmark Experiments/results/Recipe/recipe4hrs/part3\\Result_dataset_9_autos_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/results/Recipe/recipe4hrs/part3\\Result_devnagari_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/results/Recipe/recipe4hrs/part3\\Result_electricity-normalized_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/results/Recipe/recipe4hrs/part3\\Result_eye_movements_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/results/Recipe/recipe4hrs/part3\\Result_hiva_agnostic_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/results/Recipe/recipe4hrs/part3\\Result_ipums_la_99-small_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/results/Recipe/recipe4hrs/part3\\Result_leukemia_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/results/Recipe/recipe4hrs/part3\\Result_lymphoma_2classes_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/results/Recipe/recipe4hrs/part3\\Re
# ...

# %%
for f in files:
    print(f)
    data = pd.read_csv(f, header = None)
    try:
        print(data[12], '\n\n\n')
    except:
        pass
# Out:
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/results/Recipe/recipe4hrs/part3\Result_dataset_9_autos_test.csv
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/results/Recipe/recipe4hrs/part3\Result_devnagari_test.csv
# 0    0.906348
# Name: 12, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/results/Recipe/recipe4hrs/part3\Result_electricity-normalized_test.csv
# 0    0.809587
# Name: 12, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/results/Recipe/recipe4hrs/part3\Result_eye_movements_test.csv
# 0    0.756035
# Name: 12, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/results/Recipe/recipe4hrs/part3\Result_hiva_agnostic_test.csv
# 0    0.966919
# Name: 12, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/results/Recipe/recipe4hrs/part3\Result_ipums_la_99-small_test.csv
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/results/Recipe/recipe4hrs/part3\Result_leukemia_test.csv
# 0    0.833333
# ...
