# %%
import pandas as pd
import subprocess
import argparse
import os
import glob
import signal
import datetime
import time

    
def read_dataset(path):
    # All datasets available
    files_dirs = glob.glob(path + "/*.csv")
    files_dirs.sort()
    return (files_dirs)

# %%
files = read_dataset("C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2")
print(files)
# Out:
# ['C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2\\Result_aaaData_for_UCI_named_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2\\Result_analcatdata_authorship_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2\\Result_arrhythmia_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2\\Result_audiology_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2\\Result_avila-tr_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2\\Result_churn_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2\\Result_dataset_189_baseball_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2\\Result_dataset_194_eucalyptus_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2\\Result_dataset_26_nursery_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2\\Result_dataset_28_opt
# ...

# %%
for f in files:
    print(f)
    data = pd.read_csv(f, header = None)
    try:
        print(data[12], '\n\n\n')
    except:
        pass
# Out:
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2\Result_aaaData_for_UCI_named_test.csv
# 0    0.3452
# Name: 12, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2\Result_analcatdata_authorship_test.csv
# 0    0.990521
# Name: 12, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2\Result_arrhythmia_test.csv
# 0    0.530973
# Name: 12, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2\Result_audiology_test.csv
# 0    0.929825
# Name: 12, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2\Result_avila-tr_test.csv
# 0    0.950546
# Name: 12, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2\Result_churn_test.csv
# 0    0.9568
# Name: 12, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe30min_part2\Result_dataset_189_baseball_test.csv
# ...
