# %%
import pandas as pd
import subprocess
import argparse
import os
import glob
import signal
import datetime
import time

    
def read_dataset(path):
    # All datasets available
    files_dirs = glob.glob(path + "/*.csv")
    files_dirs.sort()
    return (files_dirs)

# %%
files = read_dataset("C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2")
print(files)
# Out:
# ['C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\\Result_AP_Breast_Lung_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\\Result_AP_Omentum_Ovary_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\\Result_AP_Prostate_Ovary_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\\Result_AirlinesCodrnaAdult_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\\Result_Amazon_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\\Result_CovPokElec_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\\Result_KDDCup99_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\\Result_cifar-10_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\\Result_connect-4_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\\Result_dataset_183_adult_test.csv', 'C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\\R
# ...

# %%
for f in files:
    print(f)
    data = pd.read_csv(f, header = None)
    try:
        print(data[12], '\n\n\n')
    except:
        pass
# Out:
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\Result_AP_Breast_Lung_test.csv
# 0    0.889831
# Name: 12, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\Result_AP_Omentum_Ovary_test.csv
# 0    0.811594
# Name: 12, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\Result_AP_Prostate_Ovary_test.csv
# 0    0.970149
# Name: 12, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\Result_AirlinesCodrnaAdult_test.csv
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\Result_Amazon_test.csv
# 0    0.784
# Name: 12, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\Result_CovPokElec_test.csv
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\Result_KDDCup99_test.csv
# 0    0.416307
# Name: 12, dtype: float64
#
#
#
# C:/Users/s-moh/0-Labwork/Benchmark Experiments/recipe10min2\Result_cifar-10_test.csv
# 0    0.286867
# ...
