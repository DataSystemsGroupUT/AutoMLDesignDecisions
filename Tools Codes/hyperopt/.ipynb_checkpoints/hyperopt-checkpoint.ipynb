# %%
from sklearn.datasets import fetch_mldata
from hpsklearn.estimator import hyperopt_estimator
import numpy as np
import pandas as pd
import argparse
import os
import glob
import signal
import datetime
import time
# Out:
# WARN: OMP_NUM_THREADS=None =>
# ... If you are using openblas if you are using openblas set OMP_NUM_THREADS=1 or risk subprocess calls hanging indefinitely

# %%
def hyperOpt(X_train, y_train, X_test, y_test):    
    timebud = 10 * 60
    # Create the estimator object
    #estim = HyperoptEstimator(max_evals = 1000, time_budget = timebud)
    estim = hyperopt_estimator(max_evals = 1000, time_budget = timebud, trial_timeout = 0.1 * timebud)
    print('HELLO')
    # Search the space of classifiers and preprocessing steps and their
    # respective hyperparameters in sklearn to fit a model to the data
    t1 = time.time()
    estim.fit(X_train.values, y_train)
    t2 = time.time()

    # Make a prediction using the optimized model
    #prediction = estim.predict(X_test)

    # Report the accuracy of the classifier on a given set of data
    score = estim.score(X_test.values, y_test)

    # Return instances of the classifier and preprocessing steps
    #model = estim.best_model()
    return score, t2 - t1
    #print('score:', score, ' --- time:', t2 - t1)

# %%
files_dirs = glob.glob("C:/Users/s-moh/0-Labwork/Benchmark Experiments/datasets/0/*.csv")
files_dirs.sort()
#print(files_dirs)
for file in range(0, len(files_dirs), 2):
    f1 = files_dirs[file+1]
    data = pd.read_csv(f1)
    y_train = data.iloc[:,-1]
    X_train = data.drop(data.columns[len(data.columns)-1], axis = 1)
    f2 = files_dirs[file]
    data = pd.read_csv(f2)
    y_test = data.iloc[:,-1]
    X_test = data.drop(data.columns[len(data.columns)-1], axis = 1)
    
    print('File: ', f1)
    acc, tim = hyperOpt(X_train, y_train, X_test, y_test)
    print('Accuracy: ', acc, ' --- Time:', tim)
    if(file > 20):
        break
# Out:
# File:  C:/Users/s-moh/0-Labwork/Benchmark Experiments/datasets/0\AP_Omentum_Ovary_train.csv
# HELLO
# 100%|████████████████████████████████████████████████████| 1/1 [00:37<00:00, 37.03s/it, best loss: 0.19047619047619047]
# 100%|████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.76s/it, best loss: 0.19047619047619047]
# 100%|████████████████████████████████████████████████████| 1/1 [00:04<00:00,  5.00s/it, best loss: 0.19047619047619047]
# 100%|████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.41s/it, best loss: 0.19047619047619047]
# 100%|████████████████████████████████████████████████████| 1/1 [00:56<00:00, 56.04s/it, best loss: 0.16666666666666663]
# 100%|████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.63s/it, best loss: 0.16666666666666663]
# 100%|████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.64s/it, best loss: 0.16666666666666663]
# 100%|████████████████████████████████████████████████████| 1/1 [05:07<00:00, 307.77s/it, best loss: 0.1428571428571429]
# 100%|█████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.66s/it, best loss: 0.1428571428571429]
# 100%|█████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.12s/it, best loss: 0.1428571428571429]
# 100%|█████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.34s/it, best loss: 0.1428571428571429]
# 100%|█████████████████████████████████████████████████████| 1/1 [00:33<00:00, 33.61s/it, best loss: 0.1428571428571429]
# 100%|█████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.66s/it, best loss: 0.1428571428571429]
# 100%|█████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.51s/it, best loss: 0.1428571428571429]
# 100%|█████████████████████████████████████████████████████| 1/1 [00:10<00:00, 10.56s/it, best loss: 0.1428571428571429]
# 100%|█████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.53s/it, best loss: 0.1428571428571429]
# 100%|█████████████████████████████████████████████████████| 1/1 [00:09<00:00,  9.64s/it, best loss: 0.1428571428571429]
# 100%|█████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.55s/it, best loss: 0.1428571428571429]
# 100%|█████████████████████████████████████████████████████| 1/1 [00:19<00:00, 19.41s/it, best loss: 0.1428571428571429]
# 100%|█████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.22s/it, best loss: 0.1428571428571429]
# 100%|█████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.74s/it, best loss: 0.1428571428571429]
# 100%|█████████████████████████████████████████████████████| 1/1 [00:38<00:00, 38.52s/it, best loss: 0.1428571428571429]
# Accuracy:  0.855072463768116  --- Time: 969.9993155002594
# File:  C:/Users/s-moh/0-Labwork/Benchmark Experiments/datasets/0\AP_Prostate_Ovary_train.csv
# HELLO
# 100%|███████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.50s/it, best loss: 0.025000000000000022]
# 100%|███████████████████████████████████████████████████| 1/1 [00:07<00:00,  7.92s/it, best loss: 0.025000000000000022]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.21s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.36s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.38s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.56s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:40<00:00, 40.87s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:09<00:00,  9.29s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.48s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.35s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.65s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.60s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.79s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.33s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.57s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.48s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.34s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.60s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.01s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:09<00:00,  9.57s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.75s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.56s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.62s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.36s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.52s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:07<00:00,  7.29s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:56<00:00, 56.43s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.50s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.33s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.60s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:10<00:00, 10.89s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.48s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.56s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.32s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:22<00:00, 22.21s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:07<00:00,  7.30s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.38s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.44s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.62s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.84s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.85s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.41s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.37s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.28s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.84s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.28s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.83s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.40s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.57s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.36s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:07<00:00,  7.25s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.97s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.71s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:25<00:00, 25.51s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:34<00:00, 34.68s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.35s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:08<00:00,  8.01s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.45s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.05s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.17s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:26<00:00, 26.17s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [01:13<00:00, 73.20s/it, best loss: 0.0]
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:07<00:00,  7.15s/it, best loss: 0.0]
# Accuracy:  0.9850746268656716  --- Time: 614.611857175827
# File:  C:/Users/s-moh/0-Labwork/Benchmark Experiments/datasets/0\Amazon_train.csv
# HELLO
#   0%|                                                                              | 0/1 [00:00<?, ?it/s, best loss: ?]
